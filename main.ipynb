# %%
# %matplotlib inline

# %%
import importlib
import ga.algorithm  
importlib.reload(ga.algorithm)
# Out:
# <module 'ga.algorithm' from '/Users/inakibengolea/sia-tp2/ga/algorithm.py'>

# %%
# %run main.py configs/high_fidelity.json images/munch.jpg

# %%
# %run main.py configs/r_u_m.json images/banderas/canada.png
