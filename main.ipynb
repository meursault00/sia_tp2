# %%
# %matplotlib inline

# %%
import importlib
import ga.algorithm  
importlib.reload(ga.algorithm)
# Out:
# <module 'ga.algorithm' from '/Users/felixlopez/Documents/SIA/sia_tp2/ga/algorithm.py'>

# %%
# %run main.py configs/high_fidelity.json images/banderas/canada.png
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/SIA/sia_tp2/main.py:48
#      45     print(f"Best individual's image saved as {output_file_path}")
#      47 if __name__ == "__main__":
# ---> 48     main()
#
# File ~/Documents/SIA/sia_tp2/main.py:23, in main()
#      20 target_image = load_image(image_path)
#      22 # 3. Run GA
# ---> 23 best_individual = run_ga(config, target_image)
#      25 print("\n=== GA Finished ===")
#      26 print("Best individual's fitness:", best_individual.fitness)
#
# File ~/Documents/SIA/sia_tp2/ga/algorithm.py:46, in run_ga(config, target_image)
#      44 p1, p2 = parents[i], parents[i+1]
#      45 if random.random() < config["crossover_rate"]:
# ---> 46     c1, c2 = crossover_func(p1, p2)
#      47 else:
#      48     c1, c2 = p1.clone(), p2.clone()
#
# File ~/Documents/SIA/sia_tp2/ga/crossover/two_point.py:4, in two_point_crossover(parent1, parent2)
#       3 def two_point_crossover(parent1, parent2):
# ----> 4     child1 = parent1.clone()
#       5     child2 = parent2.clone()
#       7     length = len(child1.genes)
#
# File ~/Documents/SIA/sia_tp2/ga/individual.py:27, in Individual.clone(self)
#      26 def clone(self):
# ---> 27     clone_ind = Individual(self.n_triangles, 1, 1)  # w,h no importan aquí
#      28     clone_ind.genes = [tuple(tri) for tri in self.genes]
#      29     clone_ind.fitness = self.fitness
#
# File ~/Documents/SIA/sia_tp2/ga/individual.py:11, in Individual.__init__(self, n_triangles, image_width, image_height)
#       9 def __init__(self, n_triangles, image_width, image_height):
#      10     self.n_triangles = n_triangles
# ---> 11     self.genes = self._initialize_genes(image_width, image_height)
#      12     self.fitness = None
#
# File ~/Documents/SIA/sia_tp2/ga/individual.py:17, in Individual._initialize_genes(self, w, h)
#      15 genes = []
#      16 for _ in range(self.n_triangles):
# ---> 17     x1, y1 = random.randint(0, w-1), random.randint(0, h-1)
#      18     x2, y2 = random.randint(0, w-1), random.randint(0, h-1)
#      19     x3, y3 = random.randint(0, w-1), random.randint(0, h-1)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11/random.py:362, in Random.randint(self, a, b)
#     358 def randint(self, a, b):
#     359     """Return random integer in range [a, b], including both end points.
#     360     """
# --> 362     return self.randrange(a, b+1)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.11/Frameworks/Python.framework/Versions/3.11/lib/python3.11/random.py:317, in Random.randrange(self, start, stop, step)
#     315 # stop argument supplied.
#     316 try:
# --> 317     istop = _index(stop)
#     318 except TypeError:
#     319     istop = int(stop)
#
# KeyboardInterrupt:

# %%
# %run main.py configs/r_u_m.json images/banderas/canada.png
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/SIA/sia_tp2/main.py:48
#      45     print(f"Best individual's image saved as {output_file_path}")
#      47 if __name__ == "__main__":
# ---> 48     main()
#
# File ~/Documents/SIA/sia_tp2/main.py:23, in main()
#      20 target_image = load_image(image_path)
#      22 # 3. Run GA
# ---> 23 best_individual = run_ga(config, target_image)
#      25 print("\n=== GA Finished ===")
#      26 print("Best individual's fitness:", best_individual.fitness)
#
# File ~/Documents/SIA/sia_tp2/ga/algorithm.py:60, in run_ga(config, target_image)
#      58 # #Evaluate offspring
#      59 for child in offspring:
# ---> 60     child.fitness = compute_fitness(child, target_image)
#      62 # Separation methods
#      63 if separation == "traditional":
#      64     # for ind in combined:
#      65     #     if ind.fitness is None:
#      66     #         ind.fitness = compute_fitness(ind, target_image)
#      67     # Combine entire old population + new children and select N
#
# File ~/Documents/SIA/sia_tp2/ga/fitness.py:12, in compute_fitness(individual, target_image)
#       8 generated_img = render_individual(individual, w, h)
#      10 # 2) Convertir ambas imágenes a arrays NumPy (RGBA o RGB)
#      11 #    target_image y generated_img deben tener el mismo tamaño
# ---> 12 arr_target = np.array(target_image, dtype=np.float32)
#      13 arr_generated = np.array(generated_img, dtype=np.float32)
#      15 # 3) Calcular el MSE (error cuadrático medio).
#      16 #    Asumiendo RGBA => shape = (h, w, 4)
#
# File ~/Documents/SIA/sia_tp2/my_venv/lib/python3.11/site-packages/PIL/Image.py:748, in Image.__array_interface__(self)
#     746 else:
#     747     new["data"] = self.tobytes()
# --> 748 new["shape"], new["typestr"] = _conv_type_shape(self)
#     749 return new
#
# File ~/Documents/SIA/sia_tp2/my_venv/lib/python3.11/site-packages/PIL/Image.py:250, in _conv_type_shape(im)
#     244 # --------------------------------------------------------------------
#     245 # Modes
#     247 _ENDIAN = "<" if sys.byteorder == "little" else ">"
# --> 250 def _conv_type_shape(im: Image) -> tuple[tuple[int, ...], str]:
#     251     m = ImageMode.getmode(im.mode)
#     252     shape: tuple[int, ...] = (im.height, im.width)
#
# KeyboardInterrupt:
